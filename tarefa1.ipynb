# %% [markdown]
# ## Tarefa 1
#
# gerar tabelas bivariadas relacionadas com a variavel resposta (sequela [sim/nao])

# %%
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
df = pd.read_excel('patogenese_covid.xlsx')

# %%
df.shape
# Out:
# (226, 144)

# %%
df.head()
# Out:
#    ID   grau  Idade   IMC  dias_internado FIB-CAT FVIII-CAT FVW-AG-CAT
# 0   1  GRAVE     56  29.6             2.0  Normal    Normal     Normal  \
# 1   2  GRAVE     68  28.4             5.0  Normal    Normal     Normal
# 2   3  GRAVE     68  23.8            12.0  Normal    Normal     Normal
# 3   4  GRAVE     32  36.0             8.0    HIGH      HIGH     Normal
# 4   5  GRAVE     63  27.4             9.0    HIGH      HIGH       HIGH
#
#    DD-CAT AC LÚPICO(CONCLUSÃO) a-Cl-IGG-CAT a-Cl-IGM-CAT a-B2-IGG-CAT
# 0  Normal              AUSENTE     Negativo     Negativo     Negativo  \
# 1  Normal              AUSENTE     Negativo     Negativo     Negativo
# 2  Normal              AUSENTE     Negativo     Negativo     Negativo
# 3  Normal              AUSENTE     Negativo     Negativo     Negativo
# 4    HIGH              AUSENTE     Negativo     Negativo     Negativo
#
#   a-B2-IGM-CAT CONCLUSAO-SAAF   FVL-CAT IL-6 1:2 (16/06/2022)pg/ml
# ...

# %%
df['grau'] = pd.Categorical(df['grau'], categories = ['LEVE', 'MED', 'GRAVE'])

# %%
from scipy.stats import chi2_contingency



def bivariada_sequela(coluna):
    # display(df.groupby(coluna)['apresenta_alguma_sequela'].value_counts(normalize=True).unstack().T)
    display(df.groupby('apresenta_alguma_sequela')[coluna].value_counts().unstack().fillna(0))
    display(df.groupby(coluna)['apresenta_alguma_sequela'].value_counts(normalize=True).unstack().fillna(0).T)
    # display(chi2_contingency(df.groupby('apresenta_alguma_sequela')[coluna].value_counts().unstack()))

# bivariada_sequela('grau')

# %%
df['filhos'] = df['filhos'].fillna(0)

df['trombose_familia'] = df['trombose_familia'].fillna(0)

# %%
# remove spaces from column names

df.columns = df.columns.str.replace(' ', '_')

# %%
df.head()
# Out:
#    ID   grau  Idade   IMC  dias_internado FIB-CAT FVIII-CAT FVW-AG-CAT
# 0   1  GRAVE     56  29.6             2.0  Normal    Normal     Normal  \
# 1   2  GRAVE     68  28.4             5.0  Normal    Normal     Normal
# 2   3  GRAVE     68  23.8            12.0  Normal    Normal     Normal
# 3   4  GRAVE     32  36.0             8.0    HIGH      HIGH     Normal
# 4   5  GRAVE     63  27.4             9.0    HIGH      HIGH       HIGH
#
#    DD-CAT AC_LÚPICO(CONCLUSÃO) a-Cl-IGG-CAT a-Cl-IGM-CAT a-B2-IGG-CAT
# 0  Normal              AUSENTE     Negativo     Negativo     Negativo  \
# 1  Normal              AUSENTE     Negativo     Negativo     Negativo
# 2  Normal              AUSENTE     Negativo     Negativo     Negativo
# 3  Normal              AUSENTE     Negativo     Negativo     Negativo
# 4    HIGH              AUSENTE     Negativo     Negativo     Negativo
#
#   a-B2-IGM-CAT CONCLUSAO-SAAF   FVL-CAT IL-6_1:2_(16/06/2022)pg/ml
# ...

# %%
categoricas = 'FIB-CAT	FVIII-CAT	FVW-AG-CAT	DD-CAT	AC_LÚPICO(CONCLUSÃO)	a-Cl-IGG-CAT	a-Cl-IGM-CAT	a-B2-IGG-CAT	a-B2-IGM-CAT	CONCLUSAO-SAAF	FVL-CAT IL-6-CAT TNF-α-CAT TS	HBA1c-CAT	Hb_variante	TNF-A_rs1800629	IL6_rs1800795	FV_Leiden_rs6025	FII_rs1799963	MTHFR_(C677T)	LAUDO	grupo_classificacao	proced_ncia genero	filhos j_recebeu_transfus_o_de_sa grau_de_escolaridade_analfabeta	grau_de_escolaridade_fundamental_completo	grau_de_escolaridade_fundamental_incompleto	grau_de_escolaridade_medio_completo	grau_de_escolaridade_medio_incompleto	grau_de_escolaridade_superior_completo	grau_de_escolaridade_superior_incompleto	grau_de_escolaridade_outros_pos_tec	estado_civil	raca	pratica_atividade_fisica_regularmente exame_pcr	paciente_assintom outras_pessoas_residencia_sintomas	sintomas_clinicos_ausculta_pulmonar	sintomas_clinicos_batimendo_da_asa_de_nariz	sintomas_clinicos_calafrios	sintomas_clinicos_cefaleia	sintomas_clinicos_cianose	sintomas_clinicos_coma	sintomas_clinicos_confusao_mental	sintomas_clinicos_congestao_nasal	sintomas_clinicos_conjutivite	sintomas_clinicos_convulsao	sintomas_clinicos_coriza	sintomas_clinicos_diarreia	sintomas_clinicos_falta_ar	sintomas_clinicos_dificuldade_engolir	sintomas_clinicos_dor_muscular	sintomas_clinicos_dor_na_garganta	sintomas_clinicos_dor_no_peito	sintomas_clinicos_exsudato_feringeo	sintomas_clinicos_fadiga	sintomas_clinicos_febre	sintomas_clinicos_fraqueza	sintomas_clinicos_irritabilidade	sintomas_clinicos_nausea_vomito	sintomas_clinicos_perda_olfato	sintomas_clinicos_perda_parcial_olfato	sintomas_clinicos_perda_paladar	sintomas_clinicos_perda_parcial_paladar	sintomas_clinicos_producao_escarro	sintomas_clinicos_saturacao_o2_lt_95	sintomas_clinicos_tosse	sintomas_clinicos_tontura	sintomas_clinicos_sem	sintomas_clinicos_outros	comorbidades_doenca_pulmonar_cronica	comorbidades_doenca_cardio_cronica	comorbidades_doenca_renal_cronica	comorbidades_doenca_hepatica_cronica	comorbidades_diabetes_mellitius	comorbidades_imunodeficiencia_hiv	comorbidades_tabagismo	comorbidades_neoplasia	comorbidades_avc	comorbidades_outras	comorbidades_sem	uso_de_medicamentos_nos_ultimos_10_dias	se_sim_anticoagulante_oral	se_sim_anticoncepcional	se_sim_anabolizante	se_sim_antiinflamatorio	se_sim_corticoide	se_sim_analgesico	se_sim_outros	trombose_familia	foi_vacinado_covid se_sim_qual_rede	ficou_internado_por_causa_covid oxigenoterapia	trombose	setor_de_internacao	enoxoparina	utilizou_alguma_medicacao_em_casa	medicacoes_usadas_cloroquina	medicacoes_usadas_azitromicina	medicacoes_usadas_clavulin	medicacoes_usadas_oseltamivir	medicacoes_usadas_solumedrol	medicacoes_usadas_tosiluzumabe	medicacoes_usadas_ivermectina	medicacoes_usadas_dexametasona	medicacoes_usadas_outras	se_sim_qual_quais_2___0	se_sim_qual_quais_2___1	se_sim_qual_quais_2___2	se_sim_qual_quais_2___3	se_sim_qual_quais_2___4	se_sim_qual_quais_2___5	se_sim_qual_quais_2___6	se_sim_qual_quais_2___7	se_sim_qual_quais_2___8	se_sim_qual_quais_2___9'.split()

# %%
for c in categoricas:
    
    print("*" * 50)
    print(c)
    bivariada_sequela(c)
# Out:
# **************************************************
# FIB-CAT
# FIB-CAT                   HIGH  LOW  Normal
# apresenta_alguma_sequela
# 0.0                         12    1      45
# 1.0                         40    4     123
# FIB-CAT                       HIGH  LOW    Normal
# apresenta_alguma_sequela
# 0.0                       0.230769  0.2  0.267857
# 1.0                       0.769231  0.8  0.732143
# **************************************************
# FVIII-CAT
# FVIII-CAT                 HIGH  LOW  Normal
# apresenta_alguma_sequela
# 0.0                       22.0  0.0    36.0
# 1.0                       79.0  1.0    87.0
# FVIII-CAT                     HIGH  LOW    Normal
# apresenta_alguma_sequela
# 0.0                       0.217822  0.0  0.292683
# 1.0                       0.782178  1.0  0.707317
# **************************************************
# FVW-AG-CAT
# FVW-AG-CAT                HIGH  Normal
# apresenta_alguma_sequela
# 0.0                         17      41
# ...
